# %%
import pandas as pd
import seaborn as sns

# %%
file = 'data.csv'
df = pd.read_csv(file)
print(df.head(5))
# Out:
#    Error: Check sensor connections!
# 0                            -127.0
# 1                            -127.0
# 2                            -127.0
# 3                            -127.0
# 4                            -127.0

# %%
null_values = df.isnull().sum()
print(f'null values {null_values}')
# Out:
# null values Error: Check sensor connections!    0
# dtype: int64

# %%
sns.boxplot(df)
# Out:
# <Axes: >
