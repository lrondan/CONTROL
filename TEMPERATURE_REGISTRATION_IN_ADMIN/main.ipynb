# %%
#import necesary pkg
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read the file
df = pd.read_csv("FILES/datalog_27_05.csv", header=None, names=["Date", "Time", "Temperature (°C)", "Humidity (%)"])
print('STRUCTURE')
print(df.head(1))
# Out:
# STRUCTURE
#         Date      Time  Temperature (°C)  Humidity (%)
# 0  2025/5/26  14:30:14                21            20

# %%
#Temperature plots
plt.figure(figsize=(10, 5))
plt.plot(df["Temperature (°C)"], label="Temperature", color="red")
plt.plot(df["Humidity (%)"], label="Humidity", color="blue")
plt.title("Measurement")
plt.xlabel("Data Index")
plt.ylabel("Values")
plt.grid()
plt.legend()
plt.show()

# %%
#found date and time using data index
data = int(input('Enter a new index: '))
print(df.iloc[data])
# Out:
# Enter a new index:  726
# Date                2025/5/26
# Time                   16:6:1
# Temperature (°C)           25
# Humidity (%)               38
# Name: 726, dtype: object

# %%
print(df.describe())
# Out:
#        Temperature (°C)  Humidity (%)
# count        727.000000    727.000000
# mean          25.359010     38.900963
# std            0.955842      4.326685
# min           21.000000     18.000000
# 25%           25.000000     39.000000
# 50%           26.000000     40.000000
# 75%           26.000000     41.000000
# max           26.000000     43.000000
